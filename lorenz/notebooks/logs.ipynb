# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
import os
os.getcwd()
# Out:
# '/home/GNlearning/lorenz'

# %%
# Out:
# '1-2-3'

# %%
df = pd.read_csv('artifacts/DA_logs.csv')

# %%
# pd.to_numeric(df[' nouter'])
serie = df[' nouter']

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
df
# Out:
#             #exp   ncycle   nouter                 f(x)   CGiter  \
# 0       baseline        0        0   6584.5072577740375       42
# 1       baseline        0        1    5109.035815777046       39
# 2       baseline        0        2   5003.6243929958455       36
# 3           #exp   ncycle   nouter                 f(x)   CGiter
# 4       baseline        1        0    7112.492189905748       44
# ..           ...      ...      ...                  ...      ...
# 554  Spectral_50       18        2     4901.55449157906       18
# 555         #exp   ncycle   nouter                 f(x)   CGiter
# 556  Spectral_50       19        0    6425.896985458889       19
# 557  Spectral_50       19        1    4530.974836578953       18
# 558  Spectral_50       19        2    4397.059654448176       17
#
#                   logdet                 cond             condprec
# 0     233.43857835505548   21.634683209980086   21.634683209980086
# 1     233.52906213547425    18.94417567960426    18.94417567960426
# 2      233.6501232746793   17.243231639386856   17.243231639386856
# 3                 logdet                 cond             condprec
# 4      233.9820371919973   28.807539199775558   28.807539199775558
# ..                   ...                  ...                  ...
# 554   234.22265781157364   32.682484317713396    9.302187424045098
# 555               logdet                 cond             condprec
# 556   233.26380294816417   28.492643330050274    8.934438477191843
# 557    234.8219073550488   28.660199754596956    9.204115558944473
# 558   235.05837790007394   26.188869822722378     9.18202960699459
#
# [559 rows x 8 columns]

# %%
df.nouter = pd.to_numeric(df.nouter, errors='coerce')
df.CGiter = pd.to_numeric(df.CGiter, errors='coerce')

# %%
df[df.nouter == 0]
# Out:
#             #exp ncycle  nouter                 f(x)  CGiter  \
# 0       baseline      0     0.0   6584.5072577740375    42.0
# 4       baseline      1     0.0    7112.492189905748    44.0
# 8       baseline      2     0.0     6428.22575224828    43.0
# 12      baseline      3     0.0    6761.647348699244    44.0
# 16      baseline      4     0.0    6264.098829270141    45.0
# ..           ...    ...     ...                  ...     ...
# 540  Spectral_50     15     0.0   7457.6133043059235    19.0
# 544  Spectral_50     16     0.0    8219.159999731126    20.0
# 548  Spectral_50     17     0.0   7103.5530325049185    19.0
# 552  Spectral_50     18     0.0    6947.481030543484    20.0
# 556  Spectral_50     19     0.0    6425.896985458889    19.0
#
#                   logdet                 cond             condprec
# 0     233.43857835505548   21.634683209980086   21.634683209980086
# 4      233.9820371919973   28.807539199775558   28.807539199775558
# 8     234.01654350171268   25.592524836726927   25.592524836726927
# 12       234.32458117449   29.140456943206388   29.140456943206388
# 16    233.41103501982494    30.04393123027242    30.04393123027242
# ..                   ...                  ...                  ...
# 540   233.54130996991705    35.07247332353163      9.1132821339008
# 544   233.09695053382677    32.84620662607656    9.290911757264542
# 548    233.1787836036131    33.08012515247733    8.944665018402356
# 552   232.80178231212875   24.810650859432872    8.964925340466758
# 556   233.26380294816417   28.492643330050274    8.934438477191843
#
# [140 rows x 8 columns]

# %%
sns.boxplot(df, x='nouter', y="CGiter", hue="#exp" , orient="v")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='nouter', ylabel='CGiter'>

# %%
df = pd.read_csv('artifacts/residuals.csv')

# %%
df.name
# Out:
# 0       baseline
# 1          ML_95
# 2      ML_LMP_95
# 3    Spectral_95
# 4          ML_50
# 5      ML_LMP_50
# 6    Spectral_50
# Name: name, dtype: object

# %%
list_of_df = []
for na in ['baseline', 'ML_95', 'ML_50', 'Spectral_50']:
    print(na)
    str_array = df[df['name'] == na]['residuals'].item()
    li = []
    # print(str_array.split(','))
    # print(str_array.split(' ')[:-1])
    for stri in str_array.split(',')[:-1]:
        # print(stri)
        li.append(np.fromstring(stri, dtype=float, sep=' '))
        # print(li)
    try:
        res_array = np.asarray(li).reshape(15, 3, 11)
    except ValueError:
        pass
    for i in range(3):
        _df = pd.DataFrame({'residuals': res_array[:, i, -1]})
        _df['nouter'] = i
        _df['name'] = na
        list_of_df.append(_df)
df_residuals_at_10 = pd.concat(list_of_df)
# Out:
# baseline
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/GNlearning/lorenz/logs.ipynb Cell 11 line 1
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a226465762d767432222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6f72696f6e3930227d7d/home/GNlearning/lorenz/logs.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     pass
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a226465762d767432222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6f72696f6e3930227d7d/home/GNlearning/lorenz/logs.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> for i in range(3):
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a226465762d767432222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6f72696f6e3930227d7d/home/GNlearning/lorenz/logs.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     _df = pd.DataFrame({'residuals': res_array[:, i, -1]})
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a226465762d767432222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6f72696f6e3930227d7d/home/GNlearning/lorenz/logs.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     _df['nouter'] = i
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a226465762d767432222c2273657474696e6773223a7b22686f7374223a227373683a2f2f6f72696f6e3930227d7d/home/GNlearning/lorenz/logs.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>     _df['name'] = na
#
# NameError: name 'res_array' is not defined

# %%
sns.boxplot(df_residuals_at_10, y='residuals', x='nouter', hue='name')
plt.yscale('log')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
res_array = res_array.reshape(15, 3, 11) # n_cycle= 15, n_outer = 3, n_inner=10

# %%
plt.plot(res_array[:, 0, :].T, color='k')
plt.yscale('log')
plt.plot(res_array[:,1, :].T, color='b')
plt.yscale('log')
plt.plot(res_array[:,2, :].T, color='r')
plt.yscale('log')
# Out:
# array([0.69799239, 1.01348342, 0.59738525, 0.4852701 , 0.66625554,
#        0.51833865, 0.67028026, 1.73610804, 1.29477603, 1.51497696,
#        0.75036055, 0.66579625, 0.4868392 , 0.56862003, 0.30879045])

# %%
list_of_dicts = [{'residuals': res_array[:, i, -1], 'nouter': i} for i in [0, 1, 2]]

# %%
pd.DataFrame(list_of_dicts)
# Out:
#                                            residuals  nouter
# 0  [0.6979923917125819, 1.013483418090948, 0.5973...       0
# 1  [0.25185991555352316, 0.1171099953746419, 0.20...       1
# 2  [0.056965820529721455, 0.019065794923160826, 0...       2

# %%
sns.boxplot(dff, y='residuals', x='nouter')
plt.yscale('log')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import matplotlib.pyplot as plt
plt
# Out:
# [<matplotlib.lines.Line2D at 0x7faff57e38e0>,
#  <matplotlib.lines.Line2D at 0x7faff57e3910>,
#  <matplotlib.lines.Line2D at 0x7faff57e3a00>,
#  <matplotlib.lines.Line2D at 0x7faff57e3af0>,
#  <matplotlib.lines.Line2D at 0x7faff57e3be0>,
#  <matplotlib.lines.Line2D at 0x7faff57e3cd0>,
#  <matplotlib.lines.Line2D at 0x7faff57e3dc0>,
#  <matplotlib.lines.Line2D at 0x7faff57e3eb0>,
#  <matplotlib.lines.Line2D at 0x7faff57e3fa0>,
#  <matplotlib.lines.Line2D at 0x7faff57f80d0>,
#  <matplotlib.lines.Line2D at 0x7faff57f81c0>]

# %%
import re

string = "1 2 3 (test 0, test 0) (test (0 test) 0)"


result, start_parens_count, end_parens_count, term = [], 0, 0, ""
for x in re.split(r"([()])", str_array):
    if not x.strip():
        continue
    elif x == "(":
        if start_parens_count > 0:
            term += "("
        start_parens_count += 1
    elif x == ")":
        end_parens_count += 1
        if end_parens_count == start_parens_count:
            result.append(term)
            end_parens_count, start_parens_count, term = 0, 0, ""
        else:
            term += ")"
    elif start_parens_count > end_parens_count:
        term += x
    else:
        result.extend(x.strip(" ").split(" "))


result
# Out:
# ['[[8.09741121e+01',
#  '4.33750833e+01',
#  '2.40559371e+01',
#  '1.47455917e+01',
#  '',
#  '1.03475884e+01',
#  '5.27176875e+00',
#  '2.97037826e+00',
#  '1.80380398e+00',
#  '',
#  '1.00312369e+00',
#  '5.48384415e-01',
#  '3.39321808e-01]',
#  '[2.18217153e+01',
#  '1.38214766e+01',
#  '8.04895863e+00',
#  '4.74506242e+00',
#  '',
#  '2.68599944e+00',
#  '1.71193361e+00',
#  '9.98987455e-01',
#  '5.90047347e-01',
#  '',
#  '2.98233856e-01',
#  '1.66858345e-01',
#  '1.03946111e-01]',
#  '[2.42943957e+00',
#  '1.67522947e+00',
#  '9.47462646e-01',
#  '5.91135600e-01',
#  '',
#  '4.29843595e-01',
#  '2.31376031e-01',
#  '1.52946410e-01',
#  '8.83178896e-02',
#  '',
#  '5.09535776e-02',
#  '3.71627455e-02',
#  '1.74861804e-02]',
#  '[3.74628392e-01',
#  '2.54394994e-01',
#  '1.51179914e-01',
#  '8.61356596e-02',
#  '',
#  '5.13048779e-02',
#  '3.31552626e-02',
#  '2.23354667e-02',
#  '1.31104394e-02',
#  '',
#  '7.15659863e-03',
#  '4.44120013e-03',
#  '2.45916817e-03]',
#  '[6.72167758e-02',
#  '4.26450613e-02',
#  '2.55665342e-02',
#  '1.61995435e-02',
#  '',
#  '9.47874904e-03',
#  '6.11871576e-03',
#  '3.74982240e-03',
#  '2.27697389e-03',
#  '',
#  '1.50020011e-03',
#  '9.82946727e-04',
#  '5.44212002e-04]',
#  '[9.14113944e+01',
#  '4.89334242e+01',
#  '2.42331745e+01',
#  '1.35619478e+01',
#  '',
#  '6.58667563e+00',
#  '4.84827023e+00',
#  '2.89842483e+00',
#  '1.60656267e+00',
#  '',
#  '8.98106462e-01',
#  '4.35356361e-01',
#  '2.71478420e-01]',
#  '[2.33720754e+01',
#  '1.02742753e+01',
#  '5.55698750e+00',
#  '3.36317967e+00',
#  '',
#  '2.26276548e+00',
#  '1.28196590e+00',
#  '9.13591373e-01',
#  '4.79890325e-01',
#  '',
#  '2.83251670e-01',
#  '1.57663783e-01',
#  '7.22121107e-02]',
#  '[3.99250438e+00',
#  '1.52069877e+00',
#  '9.02822159e-01',
#  '4.01599624e-01',
#  '',
#  '2.65950759e-01',
#  '1.76088675e-01',
#  '1.03817764e-01',
#  '7.00458856e-02',
#  '',
#  '4.77324161e-02',
#  '3.03696883e-02',
#  '1.28789673e-02]',
#  '[5.91231267e-01',
#  '2.61175603e-01',
#  '1.49784757e-01',
#  '8.98001827e-02',
#  '',
#  '5.25357270e-02',
#  '2.91485038e-02',
#  '1.84368198e-02',
#  '9.74861253e-03',
#  '',
#  '5.99055105e-03',
#  '3.82115389e-03',
#  '2.16916608e-03]',
#  '[1.03815014e-01',
#  '5.43357875e-02',
#  '2.84981274e-02',
#  '1.68219761e-02',
#  '',
#  '1.09146561e-02',
#  '7.57616162e-03',
#  '4.69515812e-03',
#  '2.70420705e-03',
#  '',
#  '1.91793803e-03',
#  '1.04813704e-03',
#  '5.86578131e-04]',
#  '[1.09499059e+02',
#  '6.80914785e+01',
#  '3.71831579e+01',
#  '2.32773767e+01',
#  '',
#  '1.56565826e+01',
#  '1.00781019e+01',
#  '6.40954045e+00',
#  '3.68502660e+00',
#  '',
#  '2.50406989e+00',
#  '1.77742751e+00',
#  '1.05919754e+00]',
#  '[4.52486401e+01',
#  '2.53414284e+01',
#  '1.44834763e+01',
#  '7.95141376e+00',
#  '',
#  '4.03390634e+00',
#  '2.86418400e+00',
#  '1.72961418e+00',
#  '1.05524632e+00',
#  '',
#  '6.73839421e-01',
#  '4.13565332e-01',
#  '2.48435130e-01]',
#  '[5.51157446e+00',
#  '3.55157015e+00',
#  '1.61846169e+00',
#  '8.96016873e-01',
#  '',
#  '6.79308288e-01',
#  '3.82857614e-01',
#  '2.63229563e-01',
#  '1.58527798e-01',
#  '',
#  '1.06632908e-01',
#  '6.72188365e-02',
#  '4.54699147e-02]',
#  '[7.21131414e-01',
#  '3.48847330e-01',
#  '2.04540854e-01',
#  '1.07965936e-01',
#  '',
#  '6.50356374e-02',
#  '4.03586931e-02',
#  '2.61932968e-02',
#  '1.28991744e-02',
#  '',
#  '1.00339434e-02',
#  '7.66805989e-03',
#  '4.62439561e-03]',
#  '[1.22281318e-01',
#  '6.07150043e-02',
#  '4.49881589e-02',
#  '1.92491271e-02',
#  '',
#  '1.43111760e-02',
#  '9.11274215e-03',
#  '6.13560896e-03',
#  '3.25242401e-03',
#  '',
#  '2.28009711e-03',
#  '1.53016236e-03',
#  '8.50646175e-04]]']

# %%
aa = np.array(df[df['name'] == "ML_95"]['residuals'][1])

# %%
# Out:
# ()

# %%
with open(
    "/home/data/data_data_assimilation/artifacts/CG_results_2days.pkl", "rb"
) as fhandle:
    CG_results = pickle.load(fhandle)

# %%
CG_results.keys()
# Out:
# dict_keys([23345, 70951, 93230, 116226, 139034, 161581, 198993, 235859, 271965, 298717])

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
list_dict = []

for key, val in CG_results.items():
    for method, subdict in CG_results[key].items():
        rate =subdict['rate']
        niter = np.asarray(subdict['diag']['xk']).shape[0] * 5
        print(rate, niter, method)
        list_dict.append({'rate': rate, 'niter': niter, 'method': method})
# Out:
# -0.017133389572124975 1375 baseline
# -0.0016205373669222636 2000 spectral_500
# -0.01299431174350708 1860 spectral_500_auto
# -0.0015930369787875564 2000 spectral_1000
# -0.011112088937447275 2000 spectral_1000_auto
# -0.01298254147023711 1865 spectral_500_mean
# -0.011106371832299785 2000 spectral_1000_mean
# -0.019568643085500315 1165 ML_1000_sauto_beta
# -0.02277238095009611 910 ML_1000_sauto
# -0.017071896068480964 1385 baseline
# -0.0016640607977107674 2000 spectral_500
# -0.012978087655856447 1870 spectral_500_auto
# -0.001664255102507254 2000 spectral_1000
# -0.011048347385634429 2000 spectral_1000_auto
# -0.012974838231416232 1870 spectral_500_mean
# -0.011044878282035393 2000 spectral_1000_mean
# -0.02014414224799819 1175 ML_1000_sauto_beta
# -0.023660192525670466 1045 ML_1000_sauto
# -0.01714171417193774 1380 baseline
# -0.0016641319810155842 2000 spectral_500
# -0.013039112203995708 1865 spectral_500_auto
# -0.0016782038138928143 2000 spectral_1000
# -0.011101592601925215 2000 spectral_1000_auto
# -0.013035690675189055 1865 spectral_500_mean
# -0.011096535182110899 2000 spectral_1000_mean
# -0.01971231273994278 1220 ML_1000_sauto_beta
# -0.023175479083195463 1045 ML_1000_sauto
# -0.016991509842707985 1375 baseline
# -0.001656716075298696 2000 spectral_500
# -0.012907039743640459 1865 spectral_500_auto
# -0.0016444305515406037 2000 spectral_1000
# -0.011023876065598747 2000 spectral_1000_auto
# -0.012902301772618406 1865 spectral_500_mean
# -0.01102369272249646 2000 spectral_1000_mean
# -0.0203361010400189 1125 ML_1000_sauto_beta
# -0.022443429637082294 875 ML_1000_sauto
# -0.017266715281848054 1380 baseline
# -0.001632163476556394 2000 spectral_500
# -0.013091360948200209 1870 spectral_500_auto
# -0.0016212454195793304 2000 spectral_1000
# -0.011153369351335159 2000 spectral_1000_auto
# -0.013080934784246798 1875 spectral_500_mean
# -0.011152212723393772 2000 spectral_1000_mean
# -0.01770524375639682 1265 ML_1000_sauto_beta
# -0.021228133944856037 995 ML_1000_sauto
# -0.017255789430320415 1380 baseline
# -0.0016725108623355303 2000 spectral_500
# -0.013128421945462309 1735 spectral_500_auto
# -0.0016682593980774994 2000 spectral_1000
# -0.011174051726742592 2000 spectral_1000_auto
# -0.013122518481177329 1735 spectral_500_mean
# -0.011196425265482073 2000 spectral_1000_mean
# -0.019568826780696384 1170 ML_1000_sauto_beta
# -0.02309532990599748 1040 ML_1000_sauto
# -0.017165382203700934 1375 baseline
# -0.0016801270062685003 2000 spectral_500
# -0.013030530890579567 1870 spectral_500_auto
# -0.0016691657284469473 2000 spectral_1000
# -0.011110833423800252 2000 spectral_1000_auto
# -0.013021715776521428 1870 spectral_500_mean
# -0.011101359741585834 2000 spectral_1000_mean
# -0.021249267924283975 1120 ML_1000_sauto_beta
# -0.023960216107340525 855 ML_1000_sauto
# -0.017032332445916936 1375 baseline
# -0.0016660168392589002 2000 spectral_500
# -0.012954339504364216 1865 spectral_500_auto
# -0.0016476437692357665 2000 spectral_1000
# -0.011047285342848429 2000 spectral_1000_auto
# -0.01294706255549887 1870 spectral_500_mean
# -0.011038400618380064 2000 spectral_1000_mean
# -0.020876434689132098 1115 ML_1000_sauto_beta
# -0.024220704819637277 985 ML_1000_sauto
# -0.017186381006747593 1370 baseline
# -0.0016507689071633106 2000 spectral_500
# -0.013075177963044995 1860 spectral_500_auto
# -0.0016140560382616365 2000 spectral_1000
# -0.011148400359182669 2000 spectral_1000_auto
# -0.01306211204736832 1860 spectral_500_mean
# -0.011137988967950267 2000 spectral_1000_mean
# -0.02151752201811148 1110 ML_1000_sauto_beta
# -0.024302658574810596 855 ML_1000_sauto
# -0.017244343600397512 1370 baseline
# -0.001622034481809339 2000 spectral_500
# -0.013107283410831156 1855 spectral_500_auto
# -0.0015960711937537963 2000 spectral_1000
# -0.011199971542451974 2000 spectral_1000_auto
# -0.013100332427325076 1855 spectral_500_mean
# -0.011194469085082322 2000 spectral_1000_mean
# -0.021336099046886468 1110 ML_1000_sauto_beta
# -0.02436059021157572 980 ML_1000_sauto

# %%
dataframe = pd.DataFrame(list_dict)
import matplotlib.pyplot as plt

# %%
# reduced_dataframe = dataframe.query('method == ["baseline","ML_1000_sauto","ML_1000_sauto_beta"]')
reduced_dataframe = dataframe.query('method == ["baseline","ML_1000_sauto"]')

# reduced_dataframe = dataframe.rename("baseline","ML_1000_sauto","ML_1000_sauto_beta"]')

plt.subplot(1, 2, 1)
ax = sns.boxplot(reduced_dataframe, x='method', y='rate')
ax.tick_params(axis='x', labelrotation=60)
ax.set_xticklabels(['baseline', 'ML'])
plt.title('Convergence rate')
plt.subplot(1, 2, 2)
ax = sns.boxplot(reduced_dataframe, x='method', y='niter')
ax.tick_params(axis='x', labelrotation=60)
ax.set_xticklabels(['baseline', 'ML'])

plt.title('Number of iterations to convergence')
plt.tight_layout()
# Out:
# /tmp/ipykernel_2002476/758398326.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['baseline', 'ML'])
# /tmp/ipykernel_2002476/758398326.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['baseline', 'ML'])

# %%
for key, val in CG_results.items():
    for method, subdict in CG_results[key].items():
        rate =subdict['rate']
        niter = np.asarray(subdict['diag']['xk']).shape[0] * 5
        print(rate, niter, method)
        list_dict.append({'rate': rate, 'niter': niter, 'method': method})

# %%
for key, val in CG_results.items():
    plt.plot(np.linalg.norm(np.asarray(val['baseline']['diag']['residuals']), axis=1), color='k', alpha=0.5)
    plt.plot(np.linalg.norm(np.asarray(val['baseline']['diag']['residuals']), axis=1), color='blue', alpha=0.5)
    plt.yscale('log')
