# %%
import matplotlib.pyplot as plt
import mlflow
import numpy as np
import sys, os, yaml
import pickle
import inspect


def retrieve_name(var):
        """
        Gets the name of var. Does it from the out most frame inner-wards.
        :param var: variable to get name from.
        :return: string
        """
        for fi in reversed(inspect.stack()):
            names = [var_name for var_name, var_val in fi.frame.f_locals.items() if var_val is var]
            if len(names) > 0:
                return names[0]
sys.path.append("/home/")
fig_folder = os.path.join(os.sep, "home", "smoke", "artifacts")
import tqdm
run_id_yaml = "artifacts/mlflow_run_id.yaml"
run_id = "a5fc860be53d48c9ac1573b75f1cba8f"

# %%
def bmm(a, b):
    return np.einsum("Bij,Bjk ->Bik", a, b)


def bt(a):
    return np.einsum("Bij->Bji", a)


def bouter(a, b):
    return np.einsum("Bnr,Bnr -> Bnn", a, b)


def bouter1D(a, b):
    return np.einsum("Bi,Bj -> Bij", a, b)


def bqr(a):
    Q = np.empty_like(a)
    for i, mat in enumerate(a):
        Q[i, ...] = np.linalg.qr(mat)[0]
    return Q

def printshape(*args):
    for el in args:
        try:
            print(f"{retrieve_name(el)}.shape={el.shape}")
        except e:
            pass

# %%
A_ = np.random.normal(size = (5, 20, 20))
A = bmm(bt(A_), A_)
np.linalg.slogdet(A)
# Out:
# (array([1., 1., 1., 1., 1.]),
#  array([38.93715287, 41.28794773, 43.17235335, 34.8959753 , 39.93912562]))

# %%
weights_, vectors_ = np.linalg.eigh(A)
weights, vectors = weights_[:, :]+1.0, vectors_[:, :, :]

# %%
weights.shape, vectors.shape
np.isclose((A - bmm(vectors, weights[:, :, None] * bt(vectors))), 0).all()
# Out:
# False

# %%
def low_rank_construction(Ur, Sr):
    return bmm(Ur, Sr[:, :, None] * bt(Ur))

def identity_batch(state_dimension, nbatch):
    return np.tile(np.eye(state_dimension), (nbatch, 1, 1))

id_batch = identity_batch(5, 3)

# %%
def power_singular_value_reconstructon(Ur, Sr, alpha):
    batch_size, state_dimension, rk = Ur.shape
    identity = identity_batch(state_dimension, batch_size)
    return identity + low_rank_construction(Ur, Sr ** (alpha) - 1)


low_rank_construction(vectors, weights)
# Out:
# array([[[ 1.74869518e+01, -2.40697101e-02,  3.84870217e+00, ...,
#          -2.81842192e+00, -5.70559533e+00, -7.53960227e-01],
#         [-2.40697101e-02,  1.10747386e+01, -2.44967757e+00, ...,
#          -1.51184410e+00, -3.01389323e+00,  3.91116010e+00],
#         [ 3.84870217e+00, -2.44967757e+00,  1.84387160e+01, ...,
#           1.99873972e+00,  4.15386127e-01, -3.14653660e+00],
#         ...,
#         [-2.81842192e+00, -1.51184410e+00,  1.99873972e+00, ...,
#           1.92413886e+01, -2.46305465e+00, -2.25612085e+00],
#         [-5.70559533e+00, -3.01389323e+00,  4.15386127e-01, ...,
#          -2.46305465e+00,  1.37296601e+01, -1.75561410e+00],
#         [-7.53960227e-01,  3.91116010e+00, -3.14653660e+00, ...,
#          -2.25612085e+00, -1.75561410e+00,  1.95969151e+01]],
#
#        [[ 2.09507148e+01,  7.51313067e+00, -8.43470937e-01, ...,
#          -2.00391750e+00, -1.91383777e+00,  6.99050470e+00],
#         [ 7.51313067e+00,  1.95189908e+01,  6.73377568e+00, ...,
#          -1.29920714e+00, -4.14331714e+00, -8.20369374e-01],
#         [-8.43470937e-01,  6.73377568e+00,  3.47675537e+01, ...,
#           5.41119531e+00, -1.15089991e+01, -6.18037854e+00],
#         ...,
#         [-2.00391750e+00, -1.29920714e+00,  5.41119531e+00, ...,
#           2.45365522e+01,  7.92813386e-01,  4.14085039e+00],
#         [-1.91383777e+00, -4.14331714e+00, -1.15089991e+01, ...,
#           7.92813386e-01,  3.04516274e+01,  1.03747246e+01],
#         [ 6.99050470e+00, -8.20369374e-01, -6.18037854e+00, ...,
#           4.14085039e+00,  1.03747246e+01,  1.76774387e+01]],
#
#        [[ 2.64851453e+01,  6.14208189e+00,  8.28851516e+00, ...,
#           2.69995511e+00, -1.10302024e+00,  4.19960217e+00],
#         [ 6.14208189e+00,  2.16081574e+01,  7.60786584e+00, ...,
#           9.11297680e+00,  2.63723697e+00, -6.08608351e+00],
#         [ 8.28851516e+00,  7.60786584e+00,  1.88253289e+01, ...,
#           2.85025826e+00,  3.61728924e-01,  3.04276564e+00],
#         ...,
#         [ 2.69995511e+00,  9.11297680e+00,  2.85025826e+00, ...,
#           2.45859743e+01, -2.61424407e+00, -6.79014645e+00],
#         [-1.10302024e+00,  2.63723697e+00,  3.61728924e-01, ...,
#          -2.61424407e+00,  2.73839000e+01,  5.87407241e+00],
#         [ 4.19960217e+00, -6.08608351e+00,  3.04276564e+00, ...,
#          -6.79014645e+00,  5.87407241e+00,  2.56046862e+01]],
#
#        [[ 1.89178252e+01, -5.24177852e+00, -2.17420535e+00, ...,
#           6.42545063e+00,  8.81974771e+00, -4.61092216e+00],
#         [-5.24177852e+00,  1.51903942e+01,  3.17243131e+00, ...,
#          -9.58771150e-01, -4.96857469e+00,  7.38693285e+00],
#         [-2.17420535e+00,  3.17243131e+00,  1.98906952e+01, ...,
#          -3.43887044e+00,  4.58898637e-02,  1.64778368e+00],
#         ...,
#         [ 6.42545063e+00, -9.58771150e-01, -3.43887044e+00, ...,
#           1.33521445e+01,  2.17400088e+00,  1.63138802e+00],
#         [ 8.81974771e+00, -4.96857469e+00,  4.58898637e-02, ...,
#           2.17400088e+00,  1.20847229e+01, -4.08988663e+00],
#         [-4.61092216e+00,  7.38693285e+00,  1.64778368e+00, ...,
#           1.63138802e+00, -4.08988663e+00,  3.62953132e+01]],
#
#        [[ 2.54108020e+01, -5.23384105e+00,  5.03032085e+00, ...,
#          -5.76492379e+00,  1.21822189e+00, -4.73473660e+00],
#         [-5.23384105e+00,  2.79279054e+01, -1.93207524e+00, ...,
#          -1.31256950e-01, -5.16815303e+00, -4.20550977e+00],
#         [ 5.03032085e+00, -1.93207524e+00,  2.23717189e+01, ...,
#          -8.60485701e+00, -3.43249260e+00, -7.56024614e+00],
#         ...,
#         [-5.76492379e+00, -1.31256950e-01, -8.60485701e+00, ...,
#           2.28992213e+01,  2.74177075e-01,  9.64383364e+00],
#         [ 1.21822189e+00, -5.16815303e+00, -3.43249260e+00, ...,
#           2.74177075e-01,  1.60869107e+01,  2.40097637e+00],
#         [-4.73473660e+00, -4.20550977e+00, -7.56024614e+00, ...,
#           9.64383364e+00,  2.40097637e+00,  2.65444681e+01]]])

# %%
plt.plot(np.linalg.svd(power_singular_value_reconstructon(vectors, weights, 1)[0], compute_uv=False))
plt.plot(np.linalg.svd(power_singular_value_reconstructon(vectors, weights, -1)[0], compute_uv=False))
plt.yscale('log')

# %%
# with open(run_id_yaml, "r") as fstream:
#     run_id_yaml = yaml.safe_load(fstream)
#     # run_id = run_id_yaml["run_id"]
#     data_path = run_id_yaml["data_path"]
data_path = "/root/raw_data/data_100_large/"
run_id= "08a8e575b1394c3588848cd2f947c0c0"

# %%
logged_model = f"runs:/{run_id}/smoke_model"
# mlflow.pyfunc.get_model_dependencies(logged_model)
loaded_model = mlflow.pyfunc.load_model(logged_model)
print(f"{loaded_model=}")
# Out:
# loaded_model=mlflow.pyfunc.loaded_model:
#   artifact_path: smoke_model
#   flavor: mlflow.pytorch
#   run_id: 08a8e575b1394c3588848cd2f947c0c0

# %%
# with open(data_path, "rb") as handle:
#     data = pickle.load(handle)
# x_, fo_, tlm_ = zip(*data)
x_mmap = "/root/raw_data/data_100/x.memmap"
tlm_mmap = "/root/raw_data/data_100/tlm.memmap"
nsamples=20000
dim = 100
window= 10
x_ = np.memmap(
    x_mmap,
    dtype="float32",
    mode="c",
    shape=(nsamples, dim),
)
tlm_ = np.memmap(
    tlm_mmap,
    dtype="float32",
    mode="c",
    shape=(nsamples, dim * window, dim),
)
# x_ = np.asarray(x_)

# %%
def construct_svd_ML(loaded_model, x_):
    pred = loaded_model.predict(np.asarray(x_).astype("f"))
    Ur, logsvals = pred[:, :-1, :], pred[:, -1, :]
    Sr = np.exp(logsvals)
    Ur = bqr(Ur)
    # proj = bmm(qi, (inv_sv[..., None] * bt(qi)))
    return Sr.squeeze(), Ur.squeeze()

# %%
svds = construct_svd_ML(loaded_model, x_)

# %%
tlm_[0].shape
# Out:
# (1000, 100)

# %%
Sr = svds[0]
Ur = svds[1]

# %%
Sr.shape
# Out:
# (20000, 50)

# %%
plt.plot(np.sort(Sr)[::-1].T)
# Out:
# [<matplotlib.lines.Line2D at 0x7f52b43b6230>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6290>,
#  <matplotlib.lines.Line2D at 0x7f52b43b62c0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b63b0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b64a0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6590>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6680>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6770>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6860>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6950>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6a40>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6260>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6b30>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6ce0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6dd0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6ec0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b6fb0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b70a0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7190>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7280>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7370>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7460>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7550>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7640>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7730>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7820>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7910>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7a00>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7af0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7be0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7cd0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7dc0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7eb0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b7fa0>,
#  <matplotlib.lines.Line2D at 0x7f52b42380d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42381c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42382b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42383a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4238490>,
#  <matplotlib.lines.Line2D at 0x7f52b4238580>,
#  <matplotlib.lines.Line2D at 0x7f52b4238670>,
#  <matplotlib.lines.Line2D at 0x7f52b4238760>,
#  <matplotlib.lines.Line2D at 0x7f52b4238850>,
#  <matplotlib.lines.Line2D at 0x7f52b4238940>,
#  <matplotlib.lines.Line2D at 0x7f52b4238a30>,
#  <matplotlib.lines.Line2D at 0x7f52b4238b20>,
#  <matplotlib.lines.Line2D at 0x7f52b4238c10>,
#  <matplotlib.lines.Line2D at 0x7f52b4238d00>,
#  <matplotlib.lines.Line2D at 0x7f52b4238df0>,
#  <matplotlib.lines.Line2D at 0x7f52b4238ee0>,
#  <matplotlib.lines.Line2D at 0x7f52b4238fd0>,
#  <matplotlib.lines.Line2D at 0x7f52b42390c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42391b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42392a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4239390>,
#  <matplotlib.lines.Line2D at 0x7f52b4239480>,
#  <matplotlib.lines.Line2D at 0x7f52b4239570>,
#  <matplotlib.lines.Line2D at 0x7f52b4239660>,
#  <matplotlib.lines.Line2D at 0x7f52b4239750>,
#  <matplotlib.lines.Line2D at 0x7f52b4239840>,
#  <matplotlib.lines.Line2D at 0x7f52b4239930>,
#  <matplotlib.lines.Line2D at 0x7f52b4239a20>,
#  <matplotlib.lines.Line2D at 0x7f52b4239b10>,
#  <matplotlib.lines.Line2D at 0x7f52b4239c00>,
#  <matplotlib.lines.Line2D at 0x7f52b4239cf0>,
#  <matplotlib.lines.Line2D at 0x7f52b4239de0>,
#  <matplotlib.lines.Line2D at 0x7f52b4239ed0>,
#  <matplotlib.lines.Line2D at 0x7f52b4239fc0>,
#  <matplotlib.lines.Line2D at 0x7f52b423a0b0>,
#  <matplotlib.lines.Line2D at 0x7f52b423a1a0>,
#  <matplotlib.lines.Line2D at 0x7f52b423a290>,
#  <matplotlib.lines.Line2D at 0x7f52b423a380>,
#  <matplotlib.lines.Line2D at 0x7f52b423a470>,
#  <matplotlib.lines.Line2D at 0x7f52b423a560>,
#  <matplotlib.lines.Line2D at 0x7f52b423a650>,
#  <matplotlib.lines.Line2D at 0x7f52b423a740>,
#  <matplotlib.lines.Line2D at 0x7f52b423a830>,
#  <matplotlib.lines.Line2D at 0x7f52b423a920>,
#  <matplotlib.lines.Line2D at 0x7f52b423aa10>,
#  <matplotlib.lines.Line2D at 0x7f52b423ab00>,
#  <matplotlib.lines.Line2D at 0x7f52b423abf0>,
#  <matplotlib.lines.Line2D at 0x7f52b423ace0>,
#  <matplotlib.lines.Line2D at 0x7f52b423add0>,
#  <matplotlib.lines.Line2D at 0x7f52b423aec0>,
#  <matplotlib.lines.Line2D at 0x7f52b423afb0>,
#  <matplotlib.lines.Line2D at 0x7f52b423b0a0>,
#  <matplotlib.lines.Line2D at 0x7f52b423b190>,
#  <matplotlib.lines.Line2D at 0x7f52b423b280>,
#  <matplotlib.lines.Line2D at 0x7f52b423b370>,
#  <matplotlib.lines.Line2D at 0x7f52b423b460>,
#  <matplotlib.lines.Line2D at 0x7f52b423b550>,
#  <matplotlib.lines.Line2D at 0x7f52b423b640>,
#  <matplotlib.lines.Line2D at 0x7f52b423b730>,
#  <matplotlib.lines.Line2D at 0x7f52b423b820>,
#  <matplotlib.lines.Line2D at 0x7f52b423b910>,
#  <matplotlib.lines.Line2D at 0x7f52b423ba00>,
#  <matplotlib.lines.Line2D at 0x7f52b423baf0>,
#  <matplotlib.lines.Line2D at 0x7f52b423bbe0>,
#  <matplotlib.lines.Line2D at 0x7f52b423bcd0>,
#  <matplotlib.lines.Line2D at 0x7f52b423bdc0>,
#  <matplotlib.lines.Line2D at 0x7f52b423beb0>,
#  <matplotlib.lines.Line2D at 0x7f52b423bfa0>,
#  <matplotlib.lines.Line2D at 0x7f52b42600d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42601c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42602b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42603a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4260490>,
#  <matplotlib.lines.Line2D at 0x7f52b4260580>,
#  <matplotlib.lines.Line2D at 0x7f52b4260670>,
#  <matplotlib.lines.Line2D at 0x7f52b4260760>,
#  <matplotlib.lines.Line2D at 0x7f52b4260850>,
#  <matplotlib.lines.Line2D at 0x7f52b4260940>,
#  <matplotlib.lines.Line2D at 0x7f52b4260a30>,
#  <matplotlib.lines.Line2D at 0x7f52b4260b20>,
#  <matplotlib.lines.Line2D at 0x7f52b4260c10>,
#  <matplotlib.lines.Line2D at 0x7f52b4260d00>,
#  <matplotlib.lines.Line2D at 0x7f52b4260df0>,
#  <matplotlib.lines.Line2D at 0x7f52b4260ee0>,
#  <matplotlib.lines.Line2D at 0x7f52b4260fd0>,
#  <matplotlib.lines.Line2D at 0x7f52b42610c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42611b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42612a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4261390>,
#  <matplotlib.lines.Line2D at 0x7f52b4261480>,
#  <matplotlib.lines.Line2D at 0x7f52b4261570>,
#  <matplotlib.lines.Line2D at 0x7f52b4261660>,
#  <matplotlib.lines.Line2D at 0x7f52b4261750>,
#  <matplotlib.lines.Line2D at 0x7f52b4261840>,
#  <matplotlib.lines.Line2D at 0x7f52b4261930>,
#  <matplotlib.lines.Line2D at 0x7f52b4261a20>,
#  <matplotlib.lines.Line2D at 0x7f52b4261b10>,
#  <matplotlib.lines.Line2D at 0x7f52b4261c00>,
#  <matplotlib.lines.Line2D at 0x7f52b4261cf0>,
#  <matplotlib.lines.Line2D at 0x7f52b4261de0>,
#  <matplotlib.lines.Line2D at 0x7f52b4261ed0>,
#  <matplotlib.lines.Line2D at 0x7f52b4261fc0>,
#  <matplotlib.lines.Line2D at 0x7f52b42620b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42621a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4262290>,
#  <matplotlib.lines.Line2D at 0x7f52b43b4610>,
#  <matplotlib.lines.Line2D at 0x7f52b43b44c0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b44f0>,
#  <matplotlib.lines.Line2D at 0x7f52b43f9c90>,
#  <matplotlib.lines.Line2D at 0x7f52b4419de0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b26b0>,
#  <matplotlib.lines.Line2D at 0x7f52b43b0b80>,
#  <matplotlib.lines.Line2D at 0x7f52b43b0070>,
#  <matplotlib.lines.Line2D at 0x7f52b4262470>,
#  <matplotlib.lines.Line2D at 0x7f52b42625c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42626b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42627a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4262890>,
#  <matplotlib.lines.Line2D at 0x7f52b4262980>,
#  <matplotlib.lines.Line2D at 0x7f52b4262a70>,
#  <matplotlib.lines.Line2D at 0x7f52b4262b60>,
#  <matplotlib.lines.Line2D at 0x7f52b4262c50>,
#  <matplotlib.lines.Line2D at 0x7f52b4262d40>,
#  <matplotlib.lines.Line2D at 0x7f52b4262e30>,
#  <matplotlib.lines.Line2D at 0x7f52b4262f20>,
#  <matplotlib.lines.Line2D at 0x7f52b4263010>,
#  <matplotlib.lines.Line2D at 0x7f52b4263100>,
#  <matplotlib.lines.Line2D at 0x7f52b42631f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42632e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42633d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42634c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42635b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42636a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4263790>,
#  <matplotlib.lines.Line2D at 0x7f52b4263880>,
#  <matplotlib.lines.Line2D at 0x7f52b4263970>,
#  <matplotlib.lines.Line2D at 0x7f52b4263a60>,
#  <matplotlib.lines.Line2D at 0x7f52b4263b50>,
#  <matplotlib.lines.Line2D at 0x7f52b4263c40>,
#  <matplotlib.lines.Line2D at 0x7f52b4263d30>,
#  <matplotlib.lines.Line2D at 0x7f52b4263e20>,
#  <matplotlib.lines.Line2D at 0x7f52b4263f10>,
#  <matplotlib.lines.Line2D at 0x7f52b4278040>,
#  <matplotlib.lines.Line2D at 0x7f52b4278130>,
#  <matplotlib.lines.Line2D at 0x7f52b4278220>,
#  <matplotlib.lines.Line2D at 0x7f52b4278310>,
#  <matplotlib.lines.Line2D at 0x7f52b4278400>,
#  <matplotlib.lines.Line2D at 0x7f52b42784f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42785e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42786d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42787c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42788b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42789a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4278a90>,
#  <matplotlib.lines.Line2D at 0x7f52b4278b80>,
#  <matplotlib.lines.Line2D at 0x7f52b4278c70>,
#  <matplotlib.lines.Line2D at 0x7f52b4278d60>,
#  <matplotlib.lines.Line2D at 0x7f52b4278e50>,
#  <matplotlib.lines.Line2D at 0x7f52b4278f40>,
#  <matplotlib.lines.Line2D at 0x7f52b4279030>,
#  <matplotlib.lines.Line2D at 0x7f52b4279120>,
#  <matplotlib.lines.Line2D at 0x7f52b4279210>,
#  <matplotlib.lines.Line2D at 0x7f52b4279300>,
#  <matplotlib.lines.Line2D at 0x7f52b42793f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42794e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42795d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42796c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42797b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42798a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4279990>,
#  <matplotlib.lines.Line2D at 0x7f52b4279a80>,
#  <matplotlib.lines.Line2D at 0x7f52b4279b70>,
#  <matplotlib.lines.Line2D at 0x7f52b4279c60>,
#  <matplotlib.lines.Line2D at 0x7f52b4279d50>,
#  <matplotlib.lines.Line2D at 0x7f52b4279e40>,
#  <matplotlib.lines.Line2D at 0x7f52b4279f30>,
#  <matplotlib.lines.Line2D at 0x7f52b427a020>,
#  <matplotlib.lines.Line2D at 0x7f52b427a110>,
#  <matplotlib.lines.Line2D at 0x7f52b427a200>,
#  <matplotlib.lines.Line2D at 0x7f52b427a2f0>,
#  <matplotlib.lines.Line2D at 0x7f52b427a3e0>,
#  <matplotlib.lines.Line2D at 0x7f52b427a4d0>,
#  <matplotlib.lines.Line2D at 0x7f52b427a5c0>,
#  <matplotlib.lines.Line2D at 0x7f52b427a6b0>,
#  <matplotlib.lines.Line2D at 0x7f52b427a7a0>,
#  <matplotlib.lines.Line2D at 0x7f52b427a890>,
#  <matplotlib.lines.Line2D at 0x7f52b427a980>,
#  <matplotlib.lines.Line2D at 0x7f52b427aa70>,
#  <matplotlib.lines.Line2D at 0x7f52b427ab60>,
#  <matplotlib.lines.Line2D at 0x7f52b427ac50>,
#  <matplotlib.lines.Line2D at 0x7f52b427ad40>,
#  <matplotlib.lines.Line2D at 0x7f52b427ae30>,
#  <matplotlib.lines.Line2D at 0x7f52b427af20>,
#  <matplotlib.lines.Line2D at 0x7f52b427b010>,
#  <matplotlib.lines.Line2D at 0x7f52b427b100>,
#  <matplotlib.lines.Line2D at 0x7f52b427b1f0>,
#  <matplotlib.lines.Line2D at 0x7f52b427b2e0>,
#  <matplotlib.lines.Line2D at 0x7f52b427b3d0>,
#  <matplotlib.lines.Line2D at 0x7f52b427b4c0>,
#  <matplotlib.lines.Line2D at 0x7f52b427b5b0>,
#  <matplotlib.lines.Line2D at 0x7f52b427b6a0>,
#  <matplotlib.lines.Line2D at 0x7f52b427b790>,
#  <matplotlib.lines.Line2D at 0x7f52b427b880>,
#  <matplotlib.lines.Line2D at 0x7f52b427b970>,
#  <matplotlib.lines.Line2D at 0x7f52b427ba60>,
#  <matplotlib.lines.Line2D at 0x7f52b427bb50>,
#  <matplotlib.lines.Line2D at 0x7f52b427bc40>,
#  <matplotlib.lines.Line2D at 0x7f52b427bd30>,
#  <matplotlib.lines.Line2D at 0x7f52b427be20>,
#  <matplotlib.lines.Line2D at 0x7f52b427bf10>,
#  <matplotlib.lines.Line2D at 0x7f52b4284040>,
#  <matplotlib.lines.Line2D at 0x7f52b4284130>,
#  <matplotlib.lines.Line2D at 0x7f52b4284220>,
#  <matplotlib.lines.Line2D at 0x7f52b4284310>,
#  <matplotlib.lines.Line2D at 0x7f52b4284400>,
#  <matplotlib.lines.Line2D at 0x7f52b42844f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42845e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42846d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42847c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42848b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42849a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4284a90>,
#  <matplotlib.lines.Line2D at 0x7f52b4284b80>,
#  <matplotlib.lines.Line2D at 0x7f52b4284c70>,
#  <matplotlib.lines.Line2D at 0x7f52b4284d60>,
#  <matplotlib.lines.Line2D at 0x7f52b4284e50>,
#  <matplotlib.lines.Line2D at 0x7f52b4284f40>,
#  <matplotlib.lines.Line2D at 0x7f52b4285030>,
#  <matplotlib.lines.Line2D at 0x7f52b4285120>,
#  <matplotlib.lines.Line2D at 0x7f52b4285210>,
#  <matplotlib.lines.Line2D at 0x7f52b4285300>,
#  <matplotlib.lines.Line2D at 0x7f52b42853f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42854e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42855d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42856c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42857b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42858a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4285990>,
#  <matplotlib.lines.Line2D at 0x7f52b4285a80>,
#  <matplotlib.lines.Line2D at 0x7f52b4285b70>,
#  <matplotlib.lines.Line2D at 0x7f52b4285c60>,
#  <matplotlib.lines.Line2D at 0x7f52b4285d50>,
#  <matplotlib.lines.Line2D at 0x7f52b4285e40>,
#  <matplotlib.lines.Line2D at 0x7f52b4285f30>,
#  <matplotlib.lines.Line2D at 0x7f52b4286020>,
#  <matplotlib.lines.Line2D at 0x7f52b4286110>,
#  <matplotlib.lines.Line2D at 0x7f52b4286200>,
#  <matplotlib.lines.Line2D at 0x7f52b42862f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42863e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42864d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42865c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42866b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42867a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4286890>,
#  <matplotlib.lines.Line2D at 0x7f52b4286980>,
#  <matplotlib.lines.Line2D at 0x7f52b4286a70>,
#  <matplotlib.lines.Line2D at 0x7f52b4286b60>,
#  <matplotlib.lines.Line2D at 0x7f52b4286c50>,
#  <matplotlib.lines.Line2D at 0x7f52b4286d40>,
#  <matplotlib.lines.Line2D at 0x7f52b4286e30>,
#  <matplotlib.lines.Line2D at 0x7f52b4286f20>,
#  <matplotlib.lines.Line2D at 0x7f52b4287010>,
#  <matplotlib.lines.Line2D at 0x7f52b4287100>,
#  <matplotlib.lines.Line2D at 0x7f52b42871f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42872e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42873d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42874c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42875b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42876a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4287790>,
#  <matplotlib.lines.Line2D at 0x7f52b4287880>,
#  <matplotlib.lines.Line2D at 0x7f52b4287970>,
#  <matplotlib.lines.Line2D at 0x7f52b4287a60>,
#  <matplotlib.lines.Line2D at 0x7f52b4287b50>,
#  <matplotlib.lines.Line2D at 0x7f52b4287c40>,
#  <matplotlib.lines.Line2D at 0x7f52b4287d30>,
#  <matplotlib.lines.Line2D at 0x7f52b4287e20>,
#  <matplotlib.lines.Line2D at 0x7f52b4287f10>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0040>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0130>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0220>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0310>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0400>,
#  <matplotlib.lines.Line2D at 0x7f52b42a04f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a05e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a06d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a07c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a08b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a09a0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0a90>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0b80>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0c70>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0d60>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0e50>,
#  <matplotlib.lines.Line2D at 0x7f52b42a0f40>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1030>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1120>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1210>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1300>,
#  <matplotlib.lines.Line2D at 0x7f52b42a13f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a14e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a15d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a16c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a17b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a18a0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1990>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1a80>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1b70>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1c60>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1d50>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1e40>,
#  <matplotlib.lines.Line2D at 0x7f52b42a1f30>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2020>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2110>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2200>,
#  <matplotlib.lines.Line2D at 0x7f52b42a22f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a23e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a24d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a25c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a26b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a27a0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2890>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2980>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2a70>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2b60>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2c50>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2d40>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2e30>,
#  <matplotlib.lines.Line2D at 0x7f52b42a2f20>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3010>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3100>,
#  <matplotlib.lines.Line2D at 0x7f52b42a31f0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a32e0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a33d0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a34c0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a35b0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a36a0>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3790>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3880>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3970>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3a60>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3b50>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3c40>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3d30>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3e20>,
#  <matplotlib.lines.Line2D at 0x7f52b42a3f10>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0040>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0130>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0220>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0310>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0400>,
#  <matplotlib.lines.Line2D at 0x7f52b40c04f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c05e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c06d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c07c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c08b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c09a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0a90>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0b80>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0c70>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0d60>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0e50>,
#  <matplotlib.lines.Line2D at 0x7f52b40c0f40>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1030>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1120>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1210>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1300>,
#  <matplotlib.lines.Line2D at 0x7f52b40c13f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c14e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c15d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c16c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c17b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c18a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1990>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1a80>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1b70>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1c60>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1d50>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1e40>,
#  <matplotlib.lines.Line2D at 0x7f52b40c1f30>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2020>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2110>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2200>,
#  <matplotlib.lines.Line2D at 0x7f52b40c22f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c23e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c24d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c25c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c26b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c27a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2890>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2980>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2a70>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2b60>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2c50>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2d40>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2e30>,
#  <matplotlib.lines.Line2D at 0x7f52b40c2f20>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3010>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3100>,
#  <matplotlib.lines.Line2D at 0x7f52b40c31f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c32e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c33d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c34c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c35b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c36a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3790>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3880>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3970>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3a60>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3b50>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3c40>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3d30>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3e20>,
#  <matplotlib.lines.Line2D at 0x7f52b40c3f10>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc040>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc130>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc220>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc310>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc400>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc4f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc5e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc6d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc7c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc8b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dc9a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dca90>,
#  <matplotlib.lines.Line2D at 0x7f52b40dcb80>,
#  <matplotlib.lines.Line2D at 0x7f52b40dcc70>,
#  <matplotlib.lines.Line2D at 0x7f52b40dcd60>,
#  <matplotlib.lines.Line2D at 0x7f52b40dce50>,
#  <matplotlib.lines.Line2D at 0x7f52b40dcf40>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd030>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd120>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd210>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd300>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd3f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd4e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd5d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd6c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd7b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd8a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40dd990>,
#  <matplotlib.lines.Line2D at 0x7f52b40dda80>,
#  <matplotlib.lines.Line2D at 0x7f52b40ddb70>,
#  <matplotlib.lines.Line2D at 0x7f52b40ddc60>,
#  <matplotlib.lines.Line2D at 0x7f52b40ddd50>,
#  <matplotlib.lines.Line2D at 0x7f52b40dde40>,
#  <matplotlib.lines.Line2D at 0x7f52b40ddf30>,
#  <matplotlib.lines.Line2D at 0x7f52b40de020>,
#  <matplotlib.lines.Line2D at 0x7f52b40de110>,
#  <matplotlib.lines.Line2D at 0x7f52b40de200>,
#  <matplotlib.lines.Line2D at 0x7f52b40de2f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40de3e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40de4d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40de5c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40de6b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40de7a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40de890>,
#  <matplotlib.lines.Line2D at 0x7f52b40de980>,
#  <matplotlib.lines.Line2D at 0x7f52b40dea70>,
#  <matplotlib.lines.Line2D at 0x7f52b40deb60>,
#  <matplotlib.lines.Line2D at 0x7f52b40dec50>,
#  <matplotlib.lines.Line2D at 0x7f52b40ded40>,
#  <matplotlib.lines.Line2D at 0x7f52b40dee30>,
#  <matplotlib.lines.Line2D at 0x7f52b40def20>,
#  <matplotlib.lines.Line2D at 0x7f52b40df010>,
#  <matplotlib.lines.Line2D at 0x7f52b40df100>,
#  <matplotlib.lines.Line2D at 0x7f52b40df1f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40df2e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40df3d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40df4c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40df5b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40df6a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40df790>,
#  <matplotlib.lines.Line2D at 0x7f52b40df880>,
#  <matplotlib.lines.Line2D at 0x7f52b40df970>,
#  <matplotlib.lines.Line2D at 0x7f52b40dfa60>,
#  <matplotlib.lines.Line2D at 0x7f52b40dfb50>,
#  <matplotlib.lines.Line2D at 0x7f52b40dfc40>,
#  <matplotlib.lines.Line2D at 0x7f52b40dfd30>,
#  <matplotlib.lines.Line2D at 0x7f52b40dfe20>,
#  <matplotlib.lines.Line2D at 0x7f52b40dff10>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc040>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc130>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc220>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc310>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc400>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc4f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc5e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc6d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc7c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc8b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fc9a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fca90>,
#  <matplotlib.lines.Line2D at 0x7f52b40fcb80>,
#  <matplotlib.lines.Line2D at 0x7f52b40fcc70>,
#  <matplotlib.lines.Line2D at 0x7f52b40fcd60>,
#  <matplotlib.lines.Line2D at 0x7f52b40fce50>,
#  <matplotlib.lines.Line2D at 0x7f52b40fcf40>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd030>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd120>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd210>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd300>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd3f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd4e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd5d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd6c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd7b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd8a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fd990>,
#  <matplotlib.lines.Line2D at 0x7f52b40fda80>,
#  <matplotlib.lines.Line2D at 0x7f52b40fdb70>,
#  <matplotlib.lines.Line2D at 0x7f52b40fdc60>,
#  <matplotlib.lines.Line2D at 0x7f52b40fdd50>,
#  <matplotlib.lines.Line2D at 0x7f52b40fde40>,
#  <matplotlib.lines.Line2D at 0x7f52b40fdf30>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe020>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe110>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe200>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe2f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe3e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe4d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe5c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe6b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe7a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe890>,
#  <matplotlib.lines.Line2D at 0x7f52b40fe980>,
#  <matplotlib.lines.Line2D at 0x7f52b40fea70>,
#  <matplotlib.lines.Line2D at 0x7f52b40feb60>,
#  <matplotlib.lines.Line2D at 0x7f52b40fec50>,
#  <matplotlib.lines.Line2D at 0x7f52b40fed40>,
#  <matplotlib.lines.Line2D at 0x7f52b40fee30>,
#  <matplotlib.lines.Line2D at 0x7f52b40fef20>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff010>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff100>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff1f0>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff2e0>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff3d0>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff4c0>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff5b0>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff6a0>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff790>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff880>,
#  <matplotlib.lines.Line2D at 0x7f52b40ff970>,
#  <matplotlib.lines.Line2D at 0x7f52b40ffa60>,
#  <matplotlib.lines.Line2D at 0x7f52b40ffb50>,
#  <matplotlib.lines.Line2D at 0x7f52b40ffc40>,
#  <matplotlib.lines.Line2D at 0x7f52b40ffd30>,
#  <matplotlib.lines.Line2D at 0x7f52b40ffe20>,
#  <matplotlib.lines.Line2D at 0x7f52b40fff10>,
#  <matplotlib.lines.Line2D at 0x7f52b411c040>,
#  <matplotlib.lines.Line2D at 0x7f52b411c130>,
#  <matplotlib.lines.Line2D at 0x7f52b411c220>,
#  <matplotlib.lines.Line2D at 0x7f52b411c310>,
#  <matplotlib.lines.Line2D at 0x7f52b411c400>,
#  <matplotlib.lines.Line2D at 0x7f52b411c4f0>,
#  <matplotlib.lines.Line2D at 0x7f52b411c5e0>,
#  <matplotlib.lines.Line2D at 0x7f52b411c6d0>,
#  <matplotlib.lines.Line2D at 0x7f52b411c7c0>,
#  <matplotlib.lines.Line2D at 0x7f52b411c8b0>,
#  <matplotlib.lines.Line2D at 0x7f52b411c9a0>,
#  <matplotlib.lines.Line2D at 0x7f52b411ca90>,
#  <matplotlib.lines.Line2D at 0x7f52b411cb80>,
#  <matplotlib.lines.Line2D at 0x7f52b411cc70>,
#  <matplotlib.lines.Line2D at 0x7f52b411cd60>,
#  <matplotlib.lines.Line2D at 0x7f52b411ce50>,
#  <matplotlib.lines.Line2D at 0x7f52b411cf40>,
#  <matplotlib.lines.Line2D at 0x7f52b411d030>,
#  <matplotlib.lines.Line2D at 0x7f52b411d120>,
#  <matplotlib.lines.Line2D at 0x7f52b411d210>,
#  <matplotlib.lines.Line2D at 0x7f52b411d300>,
#  <matplotlib.lines.Line2D at 0x7f52b411d3f0>,
#  <matplotlib.lines.Line2D at 0x7f52b411d4e0>,
#  <matplotlib.lines.Line2D at 0x7f52b411d5d0>,
#  <matplotlib.lines.Line2D at 0x7f52b411d6c0>,
#  <matplotlib.lines.Line2D at 0x7f52b411d7b0>,
#  <matplotlib.lines.Line2D at 0x7f52b411d8a0>,
#  <matplotlib.lines.Line2D at 0x7f52b411d990>,
#  <matplotlib.lines.Line2D at 0x7f52b411da80>,
#  <matplotlib.lines.Line2D at 0x7f52b411db70>,
#  <matplotlib.lines.Line2D at 0x7f52b411dc60>,
#  <matplotlib.lines.Line2D at 0x7f52b411dd50>,
#  <matplotlib.lines.Line2D at 0x7f52b411de40>,
#  <matplotlib.lines.Line2D at 0x7f52b411df30>,
#  <matplotlib.lines.Line2D at 0x7f52b411e020>,
#  <matplotlib.lines.Line2D at 0x7f52b411e110>,
#  <matplotlib.lines.Line2D at 0x7f52b411e200>,
#  <matplotlib.lines.Line2D at 0x7f52b411e2f0>,
#  <matplotlib.lines.Line2D at 0x7f52b411e3e0>,
#  <matplotlib.lines.Line2D at 0x7f52b411e4d0>,
#  <matplotlib.lines.Line2D at 0x7f52b411e5c0>,
#  <matplotlib.lines.Line2D at 0x7f52b411e6b0>,
#  <matplotlib.lines.Line2D at 0x7f52b411e7a0>,
#  <matplotlib.lines.Line2D at 0x7f52b411e890>,
#  <matplotlib.lines.Line2D at 0x7f52b411e980>,
#  <matplotlib.lines.Line2D at 0x7f52b411ea70>,
#  <matplotlib.lines.Line2D at 0x7f52b411eb60>,
#  <matplotlib.lines.Line2D at 0x7f52b411ec50>,
#  <matplotlib.lines.Line2D at 0x7f52b411ed40>,
#  <matplotlib.lines.Line2D at 0x7f52b411ee30>,
#  <matplotlib.lines.Line2D at 0x7f52b411ef20>,
#  <matplotlib.lines.Line2D at 0x7f52b411f010>,
#  <matplotlib.lines.Line2D at 0x7f52b411f100>,
#  <matplotlib.lines.Line2D at 0x7f52b411f1f0>,
#  <matplotlib.lines.Line2D at 0x7f52b411f2e0>,
#  <matplotlib.lines.Line2D at 0x7f52b411f3d0>,
#  <matplotlib.lines.Line2D at 0x7f52b411f4c0>,
#  <matplotlib.lines.Line2D at 0x7f52b411f5b0>,
#  <matplotlib.lines.Line2D at 0x7f52b411f6a0>,
#  <matplotlib.lines.Line2D at 0x7f52b411f790>,
#  <matplotlib.lines.Line2D at 0x7f52b411f880>,
#  <matplotlib.lines.Line2D at 0x7f52b411f970>,
#  <matplotlib.lines.Line2D at 0x7f52b411fa60>,
#  <matplotlib.lines.Line2D at 0x7f52b411fb50>,
#  <matplotlib.lines.Line2D at 0x7f52b411fc40>,
#  <matplotlib.lines.Line2D at 0x7f52b411fd30>,
#  <matplotlib.lines.Line2D at 0x7f52b411fe20>,
#  <matplotlib.lines.Line2D at 0x7f52b411ff10>,
#  <matplotlib.lines.Line2D at 0x7f52b4140040>,
#  <matplotlib.lines.Line2D at 0x7f52b4140130>,
#  <matplotlib.lines.Line2D at 0x7f52b4140220>,
#  <matplotlib.lines.Line2D at 0x7f52b4140310>,
#  <matplotlib.lines.Line2D at 0x7f52b4140400>,
#  <matplotlib.lines.Line2D at 0x7f52b41404f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41405e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41406d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41407c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41408b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41409a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4140a90>,
#  <matplotlib.lines.Line2D at 0x7f52b4140b80>,
#  <matplotlib.lines.Line2D at 0x7f52b4140c70>,
#  <matplotlib.lines.Line2D at 0x7f52b4140d60>,
#  <matplotlib.lines.Line2D at 0x7f52b4140e50>,
#  <matplotlib.lines.Line2D at 0x7f52b4140f40>,
#  <matplotlib.lines.Line2D at 0x7f52b4141030>,
#  <matplotlib.lines.Line2D at 0x7f52b4141120>,
#  <matplotlib.lines.Line2D at 0x7f52b4141210>,
#  <matplotlib.lines.Line2D at 0x7f52b4141300>,
#  <matplotlib.lines.Line2D at 0x7f52b41413f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41414e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41415d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41416c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41417b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41418a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4141990>,
#  <matplotlib.lines.Line2D at 0x7f52b4141a80>,
#  <matplotlib.lines.Line2D at 0x7f52b4141b70>,
#  <matplotlib.lines.Line2D at 0x7f52b4141c60>,
#  <matplotlib.lines.Line2D at 0x7f52b4141d50>,
#  <matplotlib.lines.Line2D at 0x7f52b4141e40>,
#  <matplotlib.lines.Line2D at 0x7f52b4141f30>,
#  <matplotlib.lines.Line2D at 0x7f52b4142020>,
#  <matplotlib.lines.Line2D at 0x7f52b4142110>,
#  <matplotlib.lines.Line2D at 0x7f52b4142200>,
#  <matplotlib.lines.Line2D at 0x7f52b41422f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41423e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41424d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41425c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41426b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41427a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4142890>,
#  <matplotlib.lines.Line2D at 0x7f52b4142980>,
#  <matplotlib.lines.Line2D at 0x7f52b4142a70>,
#  <matplotlib.lines.Line2D at 0x7f52b4142b60>,
#  <matplotlib.lines.Line2D at 0x7f52b4142c50>,
#  <matplotlib.lines.Line2D at 0x7f52b4142d40>,
#  <matplotlib.lines.Line2D at 0x7f52b4142e30>,
#  <matplotlib.lines.Line2D at 0x7f52b4142f20>,
#  <matplotlib.lines.Line2D at 0x7f52b4143010>,
#  <matplotlib.lines.Line2D at 0x7f52b4143100>,
#  <matplotlib.lines.Line2D at 0x7f52b41431f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41432e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41433d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41434c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41435b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41436a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4143790>,
#  <matplotlib.lines.Line2D at 0x7f52b4143880>,
#  <matplotlib.lines.Line2D at 0x7f52b4143970>,
#  <matplotlib.lines.Line2D at 0x7f52b4143a60>,
#  <matplotlib.lines.Line2D at 0x7f52b4143b50>,
#  <matplotlib.lines.Line2D at 0x7f52b4143c40>,
#  <matplotlib.lines.Line2D at 0x7f52b4143d30>,
#  <matplotlib.lines.Line2D at 0x7f52b4143e20>,
#  <matplotlib.lines.Line2D at 0x7f52b4143f10>,
#  <matplotlib.lines.Line2D at 0x7f52b415c040>,
#  <matplotlib.lines.Line2D at 0x7f52b415c130>,
#  <matplotlib.lines.Line2D at 0x7f52b415c220>,
#  <matplotlib.lines.Line2D at 0x7f52b415c310>,
#  <matplotlib.lines.Line2D at 0x7f52b415c400>,
#  <matplotlib.lines.Line2D at 0x7f52b415c4f0>,
#  <matplotlib.lines.Line2D at 0x7f52b415c5e0>,
#  <matplotlib.lines.Line2D at 0x7f52b415c6d0>,
#  <matplotlib.lines.Line2D at 0x7f52b415c7c0>,
#  <matplotlib.lines.Line2D at 0x7f52b415c8b0>,
#  <matplotlib.lines.Line2D at 0x7f52b415c9a0>,
#  <matplotlib.lines.Line2D at 0x7f52b415ca90>,
#  <matplotlib.lines.Line2D at 0x7f52b415cb80>,
#  <matplotlib.lines.Line2D at 0x7f52b415cc70>,
#  <matplotlib.lines.Line2D at 0x7f52b415cd60>,
#  <matplotlib.lines.Line2D at 0x7f52b415ce50>,
#  <matplotlib.lines.Line2D at 0x7f52b415cf40>,
#  <matplotlib.lines.Line2D at 0x7f52b415d030>,
#  <matplotlib.lines.Line2D at 0x7f52b415d120>,
#  <matplotlib.lines.Line2D at 0x7f52b415d210>,
#  <matplotlib.lines.Line2D at 0x7f52b415d300>,
#  <matplotlib.lines.Line2D at 0x7f52b415d3f0>,
#  <matplotlib.lines.Line2D at 0x7f52b415d4e0>,
#  <matplotlib.lines.Line2D at 0x7f52b415d5d0>,
#  <matplotlib.lines.Line2D at 0x7f52b415d6c0>,
#  <matplotlib.lines.Line2D at 0x7f52b415d7b0>,
#  <matplotlib.lines.Line2D at 0x7f52b415d8a0>,
#  <matplotlib.lines.Line2D at 0x7f52b415d990>,
#  <matplotlib.lines.Line2D at 0x7f52b415da80>,
#  <matplotlib.lines.Line2D at 0x7f52b415db70>,
#  <matplotlib.lines.Line2D at 0x7f52b415dc60>,
#  <matplotlib.lines.Line2D at 0x7f52b415dd50>,
#  <matplotlib.lines.Line2D at 0x7f52b415de40>,
#  <matplotlib.lines.Line2D at 0x7f52b415df30>,
#  <matplotlib.lines.Line2D at 0x7f52b415e020>,
#  <matplotlib.lines.Line2D at 0x7f52b415e110>,
#  <matplotlib.lines.Line2D at 0x7f52b415e200>,
#  <matplotlib.lines.Line2D at 0x7f52b415e2f0>,
#  <matplotlib.lines.Line2D at 0x7f52b415e3e0>,
#  <matplotlib.lines.Line2D at 0x7f52b415e4d0>,
#  <matplotlib.lines.Line2D at 0x7f52b415e5c0>,
#  <matplotlib.lines.Line2D at 0x7f52b415e6b0>,
#  <matplotlib.lines.Line2D at 0x7f52b415e7a0>,
#  <matplotlib.lines.Line2D at 0x7f52b415e890>,
#  <matplotlib.lines.Line2D at 0x7f52b415e980>,
#  <matplotlib.lines.Line2D at 0x7f52b415ea70>,
#  <matplotlib.lines.Line2D at 0x7f52b415eb60>,
#  <matplotlib.lines.Line2D at 0x7f52b415ec50>,
#  <matplotlib.lines.Line2D at 0x7f52b415ed40>,
#  <matplotlib.lines.Line2D at 0x7f52b415ee30>,
#  <matplotlib.lines.Line2D at 0x7f52b415ef20>,
#  <matplotlib.lines.Line2D at 0x7f52b415f010>,
#  <matplotlib.lines.Line2D at 0x7f52b415f100>,
#  <matplotlib.lines.Line2D at 0x7f52b415f1f0>,
#  <matplotlib.lines.Line2D at 0x7f52b415f2e0>,
#  <matplotlib.lines.Line2D at 0x7f52b415f3d0>,
#  <matplotlib.lines.Line2D at 0x7f52b415f4c0>,
#  <matplotlib.lines.Line2D at 0x7f52b415f5b0>,
#  <matplotlib.lines.Line2D at 0x7f52b415f6a0>,
#  <matplotlib.lines.Line2D at 0x7f52b415f790>,
#  <matplotlib.lines.Line2D at 0x7f52b415f880>,
#  <matplotlib.lines.Line2D at 0x7f52b415f970>,
#  <matplotlib.lines.Line2D at 0x7f52b415fa60>,
#  <matplotlib.lines.Line2D at 0x7f52b415fb50>,
#  <matplotlib.lines.Line2D at 0x7f52b415fc40>,
#  <matplotlib.lines.Line2D at 0x7f52b415fd30>,
#  <matplotlib.lines.Line2D at 0x7f52b415fe20>,
#  <matplotlib.lines.Line2D at 0x7f52b415ff10>,
#  <matplotlib.lines.Line2D at 0x7f52b4178040>,
#  <matplotlib.lines.Line2D at 0x7f52b4178130>,
#  <matplotlib.lines.Line2D at 0x7f52b4178220>,
#  <matplotlib.lines.Line2D at 0x7f52b4178310>,
#  <matplotlib.lines.Line2D at 0x7f52b4178400>,
#  <matplotlib.lines.Line2D at 0x7f52b41784f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41785e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41786d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41787c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41788b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41789a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4178a90>,
#  <matplotlib.lines.Line2D at 0x7f52b4178b80>,
#  <matplotlib.lines.Line2D at 0x7f52b4178c70>,
#  <matplotlib.lines.Line2D at 0x7f52b4178d60>,
#  <matplotlib.lines.Line2D at 0x7f52b4178e50>,
#  <matplotlib.lines.Line2D at 0x7f52b4178f40>,
#  <matplotlib.lines.Line2D at 0x7f52b4179030>,
#  <matplotlib.lines.Line2D at 0x7f52b4179120>,
#  <matplotlib.lines.Line2D at 0x7f52b4179210>,
#  <matplotlib.lines.Line2D at 0x7f52b4179300>,
#  <matplotlib.lines.Line2D at 0x7f52b41793f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41794e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41795d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41796c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41797b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41798a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4179990>,
#  <matplotlib.lines.Line2D at 0x7f52b4179a80>,
#  <matplotlib.lines.Line2D at 0x7f52b4179b70>,
#  <matplotlib.lines.Line2D at 0x7f52b4179c60>,
#  <matplotlib.lines.Line2D at 0x7f52b4179d50>,
#  <matplotlib.lines.Line2D at 0x7f52b4179e40>,
#  <matplotlib.lines.Line2D at 0x7f52b4179f30>,
#  <matplotlib.lines.Line2D at 0x7f52b417a020>,
#  <matplotlib.lines.Line2D at 0x7f52b417a110>,
#  <matplotlib.lines.Line2D at 0x7f52b417a200>,
#  <matplotlib.lines.Line2D at 0x7f52b417a2f0>,
#  <matplotlib.lines.Line2D at 0x7f52b417a3e0>,
#  <matplotlib.lines.Line2D at 0x7f52b417a4d0>,
#  <matplotlib.lines.Line2D at 0x7f52b417a5c0>,
#  <matplotlib.lines.Line2D at 0x7f52b417a6b0>,
#  <matplotlib.lines.Line2D at 0x7f52b417a7a0>,
#  <matplotlib.lines.Line2D at 0x7f52b417a890>,
#  <matplotlib.lines.Line2D at 0x7f52b417a980>,
#  <matplotlib.lines.Line2D at 0x7f52b417aa70>,
#  <matplotlib.lines.Line2D at 0x7f52b417ab60>,
#  <matplotlib.lines.Line2D at 0x7f52b417ac50>,
#  <matplotlib.lines.Line2D at 0x7f52b417ad40>,
#  <matplotlib.lines.Line2D at 0x7f52b417ae30>,
#  <matplotlib.lines.Line2D at 0x7f52b417af20>,
#  <matplotlib.lines.Line2D at 0x7f52b417b010>,
#  <matplotlib.lines.Line2D at 0x7f52b417b100>,
#  <matplotlib.lines.Line2D at 0x7f52b417b1f0>,
#  <matplotlib.lines.Line2D at 0x7f52b417b2e0>,
#  <matplotlib.lines.Line2D at 0x7f52b417b3d0>,
#  <matplotlib.lines.Line2D at 0x7f52b417b4c0>,
#  <matplotlib.lines.Line2D at 0x7f52b417b5b0>,
#  <matplotlib.lines.Line2D at 0x7f52b417b6a0>,
#  <matplotlib.lines.Line2D at 0x7f52b417b790>,
#  <matplotlib.lines.Line2D at 0x7f52b417b880>,
#  <matplotlib.lines.Line2D at 0x7f52b417b970>,
#  <matplotlib.lines.Line2D at 0x7f52b417ba60>,
#  <matplotlib.lines.Line2D at 0x7f52b417bb50>,
#  <matplotlib.lines.Line2D at 0x7f52b417bc40>,
#  <matplotlib.lines.Line2D at 0x7f52b417bd30>,
#  <matplotlib.lines.Line2D at 0x7f52b417be20>,
#  <matplotlib.lines.Line2D at 0x7f52b417bf10>,
#  <matplotlib.lines.Line2D at 0x7f52b4198040>,
#  <matplotlib.lines.Line2D at 0x7f52b4198130>,
#  <matplotlib.lines.Line2D at 0x7f52b4198220>,
#  <matplotlib.lines.Line2D at 0x7f52b4198310>,
#  <matplotlib.lines.Line2D at 0x7f52b4198400>,
#  <matplotlib.lines.Line2D at 0x7f52b41984f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41985e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41986d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41987c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41988b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41989a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4198a90>,
#  <matplotlib.lines.Line2D at 0x7f52b4198b80>,
#  <matplotlib.lines.Line2D at 0x7f52b4198c70>,
#  <matplotlib.lines.Line2D at 0x7f52b4198d60>,
#  <matplotlib.lines.Line2D at 0x7f52b4198e50>,
#  <matplotlib.lines.Line2D at 0x7f52b4198f40>,
#  <matplotlib.lines.Line2D at 0x7f52b4199030>,
#  <matplotlib.lines.Line2D at 0x7f52b4199120>,
#  <matplotlib.lines.Line2D at 0x7f52b4199210>,
#  <matplotlib.lines.Line2D at 0x7f52b4199300>,
#  <matplotlib.lines.Line2D at 0x7f52b41993f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41994e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41995d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41996c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41997b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41998a0>,
#  <matplotlib.lines.Line2D at 0x7f52b4199990>,
#  <matplotlib.lines.Line2D at 0x7f52b4199a80>,
#  <matplotlib.lines.Line2D at 0x7f52b4199b70>,
#  <matplotlib.lines.Line2D at 0x7f52b4199c60>,
#  <matplotlib.lines.Line2D at 0x7f52b4199d50>,
#  <matplotlib.lines.Line2D at 0x7f52b4199e40>,
#  <matplotlib.lines.Line2D at 0x7f52b4199f30>,
#  <matplotlib.lines.Line2D at 0x7f52b419a020>,
#  <matplotlib.lines.Line2D at 0x7f52b419a110>,
#  <matplotlib.lines.Line2D at 0x7f52b419a200>,
#  <matplotlib.lines.Line2D at 0x7f52b419a2f0>,
#  <matplotlib.lines.Line2D at 0x7f52b419a3e0>,
#  <matplotlib.lines.Line2D at 0x7f52b419a4d0>,
#  <matplotlib.lines.Line2D at 0x7f52b419a5c0>,
#  <matplotlib.lines.Line2D at 0x7f52b419a6b0>,
#  <matplotlib.lines.Line2D at 0x7f52b419a7a0>,
#  <matplotlib.lines.Line2D at 0x7f52b419a890>,
#  <matplotlib.lines.Line2D at 0x7f52b419a980>,
#  <matplotlib.lines.Line2D at 0x7f52b419aa70>,
#  <matplotlib.lines.Line2D at 0x7f52b419ab60>,
#  <matplotlib.lines.Line2D at 0x7f52b419ac50>,
#  <matplotlib.lines.Line2D at 0x7f52b419ad40>,
#  <matplotlib.lines.Line2D at 0x7f52b419ae30>,
#  <matplotlib.lines.Line2D at 0x7f52b419af20>,
#  <matplotlib.lines.Line2D at 0x7f52b419b010>,
#  <matplotlib.lines.Line2D at 0x7f52b419b100>,
#  <matplotlib.lines.Line2D at 0x7f52b419b1f0>,
#  <matplotlib.lines.Line2D at 0x7f52b419b2e0>,
#  <matplotlib.lines.Line2D at 0x7f52b419b3d0>,
#  <matplotlib.lines.Line2D at 0x7f52b419b4c0>,
#  <matplotlib.lines.Line2D at 0x7f52b419b5b0>,
#  <matplotlib.lines.Line2D at 0x7f52b419b6a0>,
#  <matplotlib.lines.Line2D at 0x7f52b419b790>,
#  <matplotlib.lines.Line2D at 0x7f52b419b880>,
#  <matplotlib.lines.Line2D at 0x7f52b419b970>,
#  <matplotlib.lines.Line2D at 0x7f52b419ba60>,
#  <matplotlib.lines.Line2D at 0x7f52b419bb50>,
#  <matplotlib.lines.Line2D at 0x7f52b419bc40>,
#  <matplotlib.lines.Line2D at 0x7f52b419bd30>,
#  <matplotlib.lines.Line2D at 0x7f52b419be20>,
#  <matplotlib.lines.Line2D at 0x7f52b419bf10>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0040>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0130>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0220>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0310>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0400>,
#  <matplotlib.lines.Line2D at 0x7f52b41b04f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b05e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b06d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b07c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b08b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b09a0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0a90>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0b80>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0c70>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0d60>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0e50>,
#  <matplotlib.lines.Line2D at 0x7f52b41b0f40>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1030>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1120>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1210>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1300>,
#  <matplotlib.lines.Line2D at 0x7f52b41b13f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b14e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b15d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b16c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b17b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b18a0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1990>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1a80>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1b70>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1c60>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1d50>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1e40>,
#  <matplotlib.lines.Line2D at 0x7f52b41b1f30>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2020>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2110>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2200>,
#  <matplotlib.lines.Line2D at 0x7f52b41b22f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b23e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b24d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b25c0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b26b0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b27a0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2890>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2a70>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2b90>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2bc0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2cb0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2da0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2e90>,
#  <matplotlib.lines.Line2D at 0x7f52b41b2f80>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3070>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3160>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3250>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3340>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3430>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3520>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3610>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3700>,
#  <matplotlib.lines.Line2D at 0x7f52b41b37f0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b38e0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b39d0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3ac0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3bb0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3ca0>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3d90>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3e80>,
#  <matplotlib.lines.Line2D at 0x7f52b41b3f70>,
#  <matplotlib.lines.Line2D at 0x7f52adf740a0>,
#  <matplotlib.lines.Line2D at 0x7f52adf74190>,
#  <matplotlib.lines.Line2D at 0x7f52adf74280>,
#  <matplotlib.lines.Line2D at 0x7f52adf74370>,
#  <matplotlib.lines.Line2D at 0x7f52adf74460>,
#  <matplotlib.lines.Line2D at 0x7f52adf74550>,
#  <matplotlib.lines.Line2D at 0x7f52adf74640>,
#  <matplotlib.lines.Line2D at 0x7f52adf74730>,
#  ...]

# %%
idx = 0
U_ex = Ur[idx, ...]
S_ex = Sr[idx]
A_t = tlm_[idx].T @ tlm_[idx]
A_re = U_ex @ (S_ex * U_ex).T
U_t, S_t, _ = np.linalg.svd(A_t) #U_t @ (S_t * U_t).T == A_t
printshape(U_ex, S_ex, A_t, A_re, U_t, S_t)
pinv_re = U_ex @ (S_ex**(-1) * U_ex).T

def construct_regul_thik(U, S, alpha=0.0):
    return U @ ((S / (S**2  + alpha )) * U).T
# Out:
# U_ex.shape=(100, 50)
# S_ex.shape=(50,)
# A_t.shape=(100, 100)
# A_re.shape=(100, 100)
# U_t.shape=(100, 100)
# S_t.shape=(100,)

# %%
plt.plot(np.linalg.svd(A_t, compute_uv=False)[:50])
plt.plot(np.sort(S_ex)[::-1], label='svd(A) ML')

# %%
plt.figure(figsize=(10, 8))
plt.subplot(2, 3, 1)
plt.imshow(A_t)
plt.title('true A')
plt.subplot(2, 3, 2)
plt.imshow(A_re)
plt.title('low_rank A ML ')
plt.subplot(2, 3, 3)
plt.imshow(A_t - A_re)
plt.title('diff')
plt.colorbar()
plt.subplot(2, 3, 4)
plt.plot(np.linalg.svd(A_t, compute_uv=False), label='svd(A)')
plt.plot(np.sort(S_ex)[::-1], label='svd(A) ML')
plt.plot(np.linalg.svd(A_re, compute_uv=False), ':', label="svd(A low rank ML)")
plt.legend()
plt.yscale('log')
plt.ylim(bottom=1)
plt.subplot(2, 3, 5)
plt.plot(np.linalg.svd((np.eye(100) + U_ex @ ((S_ex**(-1) - 1) * U_ex).T) @ A_t, compute_uv=False), label='ml prec')
plt.plot(np.linalg.svd((np.eye(100) + U_t[..., :50] @ ((S_t[..., :50]**(-1) - 1) * U_t[..., :50]).T) @ A_t, compute_uv=False), label='true svd preconditioner')
plt.plot(np.linalg.svd(A_t, compute_uv=False), label='svd(A_true)')
plt.yscale("log")
plt.legend()
prec_A = (np.eye(100) + U_ex @ ((S_ex**(-1) - 1) * U_ex).T) @ A_t
prec_A_t = (np.eye(100) + U_t[..., :75] @ ((S_t[..., :75]**(-1) - 1) * U_t[..., :75]).T) @ A_t
print(np.linalg.cond(A_t))
print(np.linalg.cond(prec_A))
print(np.linalg.cond(prec_A_t))
# Out:
# 15.015833
# 20.432712335967857
# 5.723192341800053

# %%
sort_idx = np.argsort(S_ex)[::-1]
U_ex = U_ex[:, sort_idx]

# %%
plt.imshow(A_t @ pinv_re @ A_t - A_t)

# %%
def inverse_iteration(A, b0, mu):
    def_A = A - mu * np.eye(A.shape[0])
    b1 = np.linalg.solve(def_A, b0)
    return b1 / np.linalg.norm(b1)

def inverse_iteration_alg(A, b0, mu, niters=5):
    b_new = b0
    for i in range(niters):
        b_new = inverse_iteration(A, b_new, mu)
    return b_new

# %%
new_U = inverse_iteration_alg(A_t, U_ex[..., 0], S_ex[0], 2)

# %%
plt.plot(new_U)
plt.plot(U_ex[..., 0])

# %%
plt.plot((A_t @ new_U) / new_U)
plt.plot((A_t @ U_ex[..., 0]) / U_ex[..., 0])

# %%
from DA_PoC.common.linalg import randomised_eigval_decomposition

# %%
W, V = randomised_eigval_decomposition(A_t, 75, 2)
print(W.shape, V.shape)
# Out:
# (75,) (100, 75)

# %%
idx = 5
plt.plot((A_t @ U_ex[:, idx] / U_ex[:, idx]) - S_ex[idx], label='ml')
plt.plot((A_t @ V[:, idx] / V[:, idx]) - W[idx], label='revd')
plt.legend()

# %%
err = []
for idx in range(75):
    err_ml = np.mean(((A_t @ U_ex[:, idx] / U_ex[:, idx]) - S_ex[idx])**2)
    err_revd = np.mean(((A_t @ V[:, idx] / V[:, idx]) - W[idx])**2)
    err.append((err_ml, err_revd))

# %%
e_ml, e_revd = zip(*err)
plt.plot(e_ml, label='ml')
plt.plot(e_revd, label='revd')
plt.yscale('log')
plt.figure()
plt.plot(np.sort(S_ex)[::-1])
plt.plot(W)
